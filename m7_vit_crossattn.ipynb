# %% [markdown]
# ### Preparation

# %%
# !pip install facenet_pytorch
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
root_dir = "/content/drive/MyDrive" # Set appropriate directory
os.chdir(root_dir)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/data.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/train/F0815/MID3/P08616_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0815/MID3/._P08616_face2.jpg
#   inflating: /content/data/train/F0029/MID6/P00295_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID6/._P00295_face4.jpg
#   inflating: /content/data/train/F0029/MID6/P00293_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID6/._P00293_face4.jpg
#   inflating: /content/data/train/F0029/MID6/P00294_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID6/._P00294_face4.jpg
#   inflating: /content/data/train/F0029/MID6/P00296_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID6/._P00296_face1.jpg
#   inflating: /content/data/train/F0029/MID1/P00294_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID1/._P00294_face5.jpg
#   inflating: /content/data/train/F0029/MID1/P00290_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID1/._P00290_face2.jpg
#   inflating: /content/data/train/F0029/MID7/P00293_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID7/._P00293_face3.jpg
#   inflating: /content/data/train/F0029/MID7/P00295_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID7/._P00295_face1.jpg
#   inflating: /content/data/train/F0029/MID7/P00296_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID7/._P00296_face2.jpg
#   inflating: /content/data/train/F0029/MID2/P00298_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00298_face1.jpg
#   inflating: /content/data/train/F0029/MID2/P00292_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00292_face3.jpg
#   inflating: /content/data/train/F0029/MID2/P00294_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00294_face2.jpg
#   inflating: /content/data/train/F0029/MID2/P00291_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00291_face1.jpg
#   inflating: /content/data/train/F0029/MID2/P00290_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00290_face1.jpg
#   inflating: /content/data/train/F0029/MID2/P00296_face6.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID2/._P00296_face6.jpg
#   inflating: /content/data/train/F0029/MID5/P00293_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID5/._P00293_face2.jpg
#   inflating: /content/data/train/F0029/MID5/P00295_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID5/._P00295_face3.jpg
#   inflating: /content/data/train/F0029/MID5/P00294_face6.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID5/._P00294_face6.jpg
#   inflating: /content/data/train/F0029/MID5/P00296_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID5/._P00296_face5.jpg
#   inflating: /content/data/train/F0029/MID4/P00295_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00295_face5.jpg
#   inflating: /content/data/train/F0029/MID4/P00292_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00292_face2.jpg
#   inflating: /content/data/train/F0029/MID4/P00294_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00294_face3.jpg
#   inflating: /content/data/train/F0029/MID4/P00299_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00299_face1.jpg
#   inflating: /content/data/train/F0029/MID4/P00297_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00297_face2.jpg
#   inflating: /content/data/train/F0029/MID4/P00296_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID4/._P00296_face3.jpg
#   inflating: /content/data/train/F0029/MID3/P00293_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00293_face1.jpg
#   inflating: /content/data/train/F0029/MID3/P00295_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00295_face2.jpg
#   inflating: /content/data/train/F0029/MID3/P00298_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00298_face2.jpg
#   inflating: /content/data/train/F0029/MID3/P00292_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00292_face1.jpg
#   inflating: /content/data/train/F0029/MID3/P00299_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00299_face2.jpg
#   inflating: /content/data/train/F0029/MID3/P00294_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00294_face1.jpg
#   inflating: /content/data/train/F0029/MID3/P00291_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00291_face2.jpg
#   inflating: /content/data/train/F0029/MID3/P00297_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00297_face1.jpg
#   inflating: /content/data/train/F0029/MID3/P00296_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0029/MID3/._P00296_face4.jpg
#   inflating: /content/data/train/F0481/MID6/P05069_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID6/._P05069_face2.jpg
#   inflating: /content/data/train/F0481/MID6/P05072_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID6/._P05072_face2.jpg
#   inflating: /content/data/train/F0481/MID6/P05066_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID6/._P05066_face4.jpg
#   inflating: /content/data/train/F0481/MID1/P05069_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05069_face3.jpg
#   inflating: /content/data/train/F0481/MID1/P05070_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05070_face2.jpg
#   inflating: /content/data/train/F0481/MID1/P05071_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05071_face1.jpg
#   inflating: /content/data/train/F0481/MID1/P05068_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05068_face1.jpg
#   inflating: /content/data/train/F0481/MID1/P05066_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05066_face3.jpg
#   inflating: /content/data/train/F0481/MID1/P05074_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05074_face3.jpg
#   inflating: /content/data/train/F0481/MID1/P05073_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05073_face1.jpg
#   inflating: /content/data/train/F0481/MID1/P05075_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID1/._P05075_face1.jpg
#   inflating: /content/data/train/F0481/MID8/P05072_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID8/._P05072_face1.jpg
#   inflating: /content/data/train/F0481/MID8/P05073_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID8/._P05073_face2.jpg
#   inflating: /content/data/train/F0481/MID9/P05073_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID9/._P05073_face3.jpg
#   inflating: /content/data/train/F0481/MID2/P05069_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID2/._P05069_face1.jpg
#   inflating: /content/data/train/F0481/MID2/P05066_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID2/._P05066_face1.jpg
#   inflating: /content/data/train/F0481/MID2/P05067_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID2/._P05067_face1.jpg
#   inflating: /content/data/train/F0481/MID5/P05074_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID5/._P05074_face1.jpg
#   inflating: /content/data/train/F0481/MID5/P05066_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID5/._P05066_face5.jpg
#   inflating: /content/data/train/F0481/MID5/P05067_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID5/._P05067_face3.jpg
#   inflating: /content/data/train/F0481/MID4/P05071_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID4/._P05071_face2.jpg
#   inflating: /content/data/train/F0481/MID4/P05066_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID4/._P05066_face2.jpg
#   inflating: /content/data/train/F0481/MID4/P05074_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID4/._P05074_face2.jpg
#   inflating: /content/data/train/F0481/MID4/P05067_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID4/._P05067_face2.jpg
#   inflating: /content/data/train/F0481/MID3/P05070_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID3/._P05070_face1.jpg
#   inflating: /content/data/train/F0481/MID3/P05067_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0481/MID3/._P05067_face4.jpg
#   inflating: /content/data/train/F0011/MID1/P00114_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID1/._P00114_face3.jpg
#   inflating: /content/data/train/F0011/MID1/P00122_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID1/._P00122_face1.jpg
#   inflating: /content/data/train/F0011/MID1/P00117_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID1/._P00117_face1.jpg
#   inflating: /content/data/train/F0011/MID2/P00114_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00114_face2.jpg
#   inflating: /content/data/train/F0011/MID2/P00113_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00113_face1.jpg
#   inflating: /content/data/train/F0011/MID2/P00118_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00118_face2.jpg
#   inflating: /content/data/train/F0011/MID2/P00115_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00115_face1.jpg
#   inflating: /content/data/train/F0011/MID2/P00116_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00116_face2.jpg
#   inflating: /content/data/train/F0011/MID2/P00117_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID2/._P00117_face2.jpg
#   inflating: /content/data/train/F0011/MID3/P00119_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID3/._P00119_face2.jpg
#   inflating: /content/data/train/F0011/MID3/P00114_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID3/._P00114_face1.jpg
#   inflating: /content/data/train/F0011/MID3/P00118_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID3/._P00118_face1.jpg
#   inflating: /content/data/train/F0011/MID3/P00116_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0011/MID3/._P00116_face1.jpg
#   inflating: /content/data/train/F0223/MID1/P02371_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02371_face2.jpg
#   inflating: /content/data/train/F0223/MID1/P02368_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02368_face1.jpg
#   inflating: /content/data/train/F0223/MID1/P02365_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02365_face1.jpg
#   inflating: /content/data/train/F0223/MID1/P02369_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02369_face3.jpg
#   inflating: /content/data/train/F0223/MID1/P02370_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02370_face1.jpg
#   inflating: /content/data/train/F0223/MID1/P02367_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02367_face4.jpg
#   inflating: /content/data/train/F0223/MID1/P02373_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02373_face1.jpg
#   inflating: /content/data/train/F0223/MID1/P02374_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02374_face2.jpg
#   inflating: /content/data/train/F0223/MID1/P02372_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02372_face2.jpg
#   inflating: /content/data/train/F0223/MID1/P02366_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID1/._P02366_face1.jpg
#   inflating: /content/data/train/F0223/MID2/P02365_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02365_face3.jpg
#   inflating: /content/data/train/F0223/MID2/P02371_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02371_face3.jpg
#   inflating: /content/data/train/F0223/MID2/P02368_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02368_face2.jpg
#   inflating: /content/data/train/F0223/MID2/P02370_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02370_face4.jpg
#   inflating: /content/data/train/F0223/MID2/P02369_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02369_face4.jpg
#   inflating: /content/data/train/F0223/MID2/P02373_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02373_face5.jpg
#   inflating: /content/data/train/F0223/MID2/P02367_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02367_face1.jpg
#   inflating: /content/data/train/F0223/MID2/P02374_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02374_face3.jpg
#   inflating: /content/data/train/F0223/MID2/P02366_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID2/._P02366_face3.jpg
#   inflating: /content/data/train/F0223/MID5/P02370_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID5/._P02370_face5.jpg
#   inflating: /content/data/train/F0223/MID5/P02374_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID5/._P02374_face5.jpg
#   inflating: /content/data/train/F0223/MID4/P02365_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02365_face5.jpg
#   inflating: /content/data/train/F0223/MID4/P02369_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02369_face5.jpg
#   inflating: /content/data/train/F0223/MID4/P02370_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02370_face3.jpg
#   inflating: /content/data/train/F0223/MID4/P02367_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02367_face3.jpg
#   inflating: /content/data/train/F0223/MID4/P02373_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02373_face3.jpg
#   inflating: /content/data/train/F0223/MID4/P02366_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02366_face4.jpg
#   inflating: /content/data/train/F0223/MID4/P02374_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02374_face4.jpg
#   inflating: /content/data/train/F0223/MID4/P02372_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID4/._P02372_face1.jpg
#   inflating: /content/data/train/F0223/MID3/P02365_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02365_face2.jpg
#   inflating: /content/data/train/F0223/MID3/P02371_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02371_face1.jpg
#   inflating: /content/data/train/F0223/MID3/P02369_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02369_face1.jpg
#   inflating: /content/data/train/F0223/MID3/P02370_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02370_face2.jpg
#   inflating: /content/data/train/F0223/MID3/P02373_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02373_face2.jpg
#   inflating: /content/data/train/F0223/MID3/P02367_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02367_face2.jpg
#   inflating: /content/data/train/F0223/MID3/P02374_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02374_face1.jpg
#   inflating: /content/data/train/F0223/MID3/P02366_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02366_face2.jpg
#   inflating: /content/data/train/F0223/MID3/P02372_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0223/MID3/._P02372_face3.jpg
#   inflating: /content/data/train/F0647/MID1/P06821_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06821_face2.jpg
#   inflating: /content/data/train/F0647/MID1/P06827_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06827_face4.jpg
#   inflating: /content/data/train/F0647/MID1/P06814_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06814_face2.jpg
#   inflating: /content/data/train/F0647/MID1/P06818_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06818_face2.jpg
#   inflating: /content/data/train/F0647/MID1/P06826_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06826_face2.jpg
#   inflating: /content/data/train/F0647/MID1/P06813_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06813_face1.jpg
#   inflating: /content/data/train/F0647/MID1/P06825_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06825_face1.jpg
#   inflating: /content/data/train/F0647/MID1/P06817_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06817_face2.jpg
#   inflating: /content/data/train/F0647/MID1/P06822_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID1/._P06822_face2.jpg
#   inflating: /content/data/train/F0647/MID2/P06827_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06827_face3.jpg
#   inflating: /content/data/train/F0647/MID2/P06818_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06818_face1.jpg
#   inflating: /content/data/train/F0647/MID2/P06815_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06815_face1.jpg
#   inflating: /content/data/train/F0647/MID2/P06813_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06813_face2.jpg
#   inflating: /content/data/train/F0647/MID2/P06826_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06826_face1.jpg
#   inflating: /content/data/train/F0647/MID2/P06816_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06816_face1.jpg
#   inflating: /content/data/train/F0647/MID2/P06825_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06825_face2.jpg
#   inflating: /content/data/train/F0647/MID2/P06817_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06817_face1.jpg
#   inflating: /content/data/train/F0647/MID2/P06822_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID2/._P06822_face1.jpg
#   inflating: /content/data/train/F0647/MID4/P06814_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID4/._P06814_face1.jpg
#   inflating: /content/data/train/F0647/MID4/P06827_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID4/._P06827_face2.jpg
#   inflating: /content/data/train/F0647/MID4/P06818_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID4/._P06818_face3.jpg
#   inflating: /content/data/train/F0647/MID3/P06821_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID3/._P06821_face1.jpg
#   inflating: /content/data/train/F0647/MID3/P06813_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0647/MID3/._P06813_face3.jpg
#   inflating: /content/data/train/F0475/MID6/P11782_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11782_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11790_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11790_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11784_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11784_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11775_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11775_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11789_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11789_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11783_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11783_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11788_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11788_face2.jpg
#   inflating: /content/data/train/F0475/MID6/P11791_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11791_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11785_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11785_face2.jpg
#   inflating: /content/data/train/F0475/MID6/P11792_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11792_face1.jpg
#   inflating: /content/data/train/F0475/MID6/P11786_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11786_face2.jpg
#   inflating: /content/data/train/F0475/MID6/P11776_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID6/._P11776_face2.jpg
#   inflating: /content/data/train/F0475/MID1/P04998_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID1/._P04998_face1.jpg
#   inflating: /content/data/train/F0475/MID1/P05001_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID1/._P05001_face1.jpg
#   inflating: /content/data/train/F0475/MID1/P04999_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID1/._P04999_face2.jpg
#   inflating: /content/data/train/F0475/MID1/P05000_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID1/._P05000_face2.jpg
#   inflating: /content/data/train/F0475/MID1/P04997_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID1/._P04997_face1.jpg
#   inflating: /content/data/train/F0475/MID8/P11788_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID8/._P11788_face3.jpg
#   inflating: /content/data/train/F0475/MID7/P11785_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID7/._P11785_face1.jpg
#   inflating: /content/data/train/F0475/MID2/P04998_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID2/._P04998_face2.jpg
#   inflating: /content/data/train/F0475/MID2/P05001_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID2/._P05001_face2.jpg
#   inflating: /content/data/train/F0475/MID2/P11774_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID2/._P11774_face1.jpg
#   inflating: /content/data/train/F0475/MID2/P04997_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID2/._P04997_face2.jpg
#   inflating: /content/data/train/F0475/MID5/P11778_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID5/._P11778_face1.jpg
#   inflating: /content/data/train/F0475/MID5/P11779_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID5/._P11779_face1.jpg
#   inflating: /content/data/train/F0475/MID5/P11777_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID5/._P11777_face1.jpg
#   inflating: /content/data/train/F0475/MID5/P11781_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID5/._P11781_face1.jpg
#   inflating: /content/data/train/F0475/MID5/P11776_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID5/._P11776_face1.jpg
#   inflating: /content/data/train/F0475/MID4/P11786_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID4/._P11786_face1.jpg
#   inflating: /content/data/train/F0475/MID4/P11787_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID4/._P11787_face1.jpg
#   inflating: /content/data/train/F0475/MID3/P11782_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID3/._P11782_face2.jpg
#   inflating: /content/data/train/F0475/MID3/P11784_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID3/._P11784_face2.jpg
#   inflating: /content/data/train/F0475/MID3/P11783_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID3/._P11783_face2.jpg
#   inflating: /content/data/train/F0475/MID3/P04999_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID3/._P04999_face1.jpg
#   inflating: /content/data/train/F0475/MID3/P05000_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0475/MID3/._P05000_face1.jpg
#   inflating: /content/data/train/F0678/MID1/P07078_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07078_face1.jpg
#   inflating: /content/data/train/F0678/MID1/P07073_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07073_face2.jpg
#   inflating: /content/data/train/F0678/MID1/P07079_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07079_face2.jpg
#   inflating: /content/data/train/F0678/MID1/P07074_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07074_face1.jpg
#   inflating: /content/data/train/F0678/MID1/P07077_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07077_face1.jpg
#   inflating: /content/data/train/F0678/MID1/P07080_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07080_face1.jpg
#   inflating: /content/data/train/F0678/MID1/P07081_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID1/._P07081_face1.jpg
#   inflating: /content/data/train/F0678/MID2/P07078_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID2/._P07078_face2.jpg
#   inflating: /content/data/train/F0678/MID2/P07073_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID2/._P07073_face1.jpg
#   inflating: /content/data/train/F0678/MID2/P07079_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID2/._P07079_face1.jpg
#   inflating: /content/data/train/F0678/MID5/P07080_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID5/._P07080_face2.jpg
#   inflating: /content/data/train/F0678/MID4/P07075_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID4/._P07075_face1.jpg
#   inflating: /content/data/train/F0678/MID4/P07077_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0678/MID4/._P07077_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08580_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08580_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08592_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08592_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08586_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08586_face1.jpg
#   inflating: /content/data/train/F0812/MID1/P08581_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08581_face3.jpg
#   inflating: /content/data/train/F0812/MID1/P08587_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08587_face3.jpg
#   inflating: /content/data/train/F0812/MID1/P08593_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08593_face3.jpg
#   inflating: /content/data/train/F0812/MID1/P08584_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08584_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08582_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08582_face4.jpg
#   inflating: /content/data/train/F0812/MID1/P08589_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08589_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08583_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08583_face3.jpg
#   inflating: /content/data/train/F0812/MID1/P08591_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08591_face2.jpg
#   inflating: /content/data/train/F0812/MID1/P08585_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08585_face1.jpg
#   inflating: /content/data/train/F0812/MID1/P08588_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID1/._P08588_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08580_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08580_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08586_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08586_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08592_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08592_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08581_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08581_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08593_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08593_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08587_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08587_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08582_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08582_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08589_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08589_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08584_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08584_face1.jpg
#   inflating: /content/data/train/F0812/MID2/P08583_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08583_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08585_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08585_face2.jpg
#   inflating: /content/data/train/F0812/MID2/P08591_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08591_face3.jpg
#   inflating: /content/data/train/F0812/MID2/P08588_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID2/._P08588_face3.jpg
#   inflating: /content/data/train/F0812/MID3/P08587_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08587_face4.jpg
#   inflating: /content/data/train/F0812/MID3/P08581_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08581_face1.jpg
#   inflating: /content/data/train/F0812/MID3/P08593_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08593_face1.jpg
#   inflating: /content/data/train/F0812/MID3/P08582_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08582_face3.jpg
#   inflating: /content/data/train/F0812/MID3/P08583_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08583_face1.jpg
#   inflating: /content/data/train/F0812/MID3/P08588_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08588_face1.jpg
#   inflating: /content/data/train/F0812/MID3/P08585_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08585_face3.jpg
#   inflating: /content/data/train/F0812/MID3/P08591_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0812/MID3/._P08591_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07149_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07149_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07150_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07150_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07165_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07165_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07156_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07156_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07151_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07151_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07162_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07162_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07157_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07157_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07159_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07159_face4.jpg
#   inflating: /content/data/train/F0685/MID1/P07154_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07154_face3.jpg
#   inflating: /content/data/train/F0685/MID1/P07161_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07161_face1.jpg
#   inflating: /content/data/train/F0685/MID1/P07153_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07153_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07155_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07155_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07160_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07160_face2.jpg
#   inflating: /content/data/train/F0685/MID1/P07158_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID1/._P07158_face2.jpg
#   inflating: /content/data/train/F0685/MID2/P07149_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID2/._P07149_face1.jpg
#   inflating: /content/data/train/F0685/MID2/P07150_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID2/._P07150_face4.jpg
#   inflating: /content/data/train/F0685/MID2/P07151_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID2/._P07151_face1.jpg
#   inflating: /content/data/train/F0685/MID2/P07161_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID2/._P07161_face3.jpg
#   inflating: /content/data/train/F0685/MID2/P07158_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID2/._P07158_face3.jpg
#   inflating: /content/data/train/F0685/MID5/P07165_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07165_face2.jpg
#   inflating: /content/data/train/F0685/MID5/P07163_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07163_face3.jpg
#   inflating: /content/data/train/F0685/MID5/P07156_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07156_face2.jpg
#   inflating: /content/data/train/F0685/MID5/P07164_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07164_face2.jpg
#   inflating: /content/data/train/F0685/MID5/P07162_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07162_face1.jpg
#   inflating: /content/data/train/F0685/MID5/P07154_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07154_face2.jpg
#   inflating: /content/data/train/F0685/MID5/P07161_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07161_face2.jpg
#   inflating: /content/data/train/F0685/MID5/P07159_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07159_face3.jpg
#   inflating: /content/data/train/F0685/MID5/P07153_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07153_face4.jpg
#   inflating: /content/data/train/F0685/MID5/P07155_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID5/._P07155_face1.jpg
#   inflating: /content/data/train/F0685/MID4/P07156_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID4/._P07156_face4.jpg
#   inflating: /content/data/train/F0685/MID4/P07159_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID4/._P07159_face2.jpg
#   inflating: /content/data/train/F0685/MID4/P07153_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID4/._P07153_face3.jpg
#   inflating: /content/data/train/F0685/MID3/P07156_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07156_face3.jpg
#   inflating: /content/data/train/F0685/MID3/P07163_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07163_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07164_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07164_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07157_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07157_face2.jpg
#   inflating: /content/data/train/F0685/MID3/P07159_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07159_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07154_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07154_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07153_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07153_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07158_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07158_face1.jpg
#   inflating: /content/data/train/F0685/MID3/P07160_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0685/MID3/._P07160_face1.jpg
#   inflating: /content/data/train/F0443/MID6/P04679_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID6/._P04679_face2.jpg
#   inflating: /content/data/train/F0443/MID6/P04672_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID6/._P04672_face2.jpg
#   inflating: /content/data/train/F0443/MID1/P04677_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04677_face2.jpg
#   inflating: /content/data/train/F0443/MID1/P04680_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04680_face3.jpg
#   inflating: /content/data/train/F0443/MID1/P04676_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04676_face2.jpg
#   inflating: /content/data/train/F0443/MID1/P04681_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04681_face1.jpg
#   inflating: /content/data/train/F0443/MID1/P04675_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04675_face1.jpg
#   inflating: /content/data/train/F0443/MID1/P04678_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04678_face1.jpg
#   inflating: /content/data/train/F0443/MID1/P04673_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04673_face1.jpg
#   inflating: /content/data/train/F0443/MID1/P04679_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04679_face1.jpg
#   inflating: /content/data/train/F0443/MID1/P04674_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04674_face2.jpg
#   inflating: /content/data/train/F0443/MID1/P04672_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID1/._P04672_face1.jpg
#   inflating: /content/data/train/F0443/MID2/P04675_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID2/._P04675_face2.jpg
#   inflating: /content/data/train/F0443/MID2/P04673_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID2/._P04673_face2.jpg
#   inflating: /content/data/train/F0443/MID2/P04674_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID2/._P04674_face1.jpg
#   inflating: /content/data/train/F0443/MID5/P04680_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID5/._P04680_face2.jpg
#   inflating: /content/data/train/F0443/MID5/P04677_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID5/._P04677_face4.jpg
#   inflating: /content/data/train/F0443/MID5/P04681_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID5/._P04681_face4.jpg
#   inflating: /content/data/train/F0443/MID5/P04676_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID5/._P04676_face3.jpg
#   inflating: /content/data/train/F0443/MID5/P04678_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID5/._P04678_face3.jpg
#   inflating: /content/data/train/F0443/MID4/P04677_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID4/._P04677_face1.jpg
#   inflating: /content/data/train/F0443/MID4/P04680_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID4/._P04680_face1.jpg
#   inflating: /content/data/train/F0443/MID4/P04676_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID4/._P04676_face1.jpg
#   inflating: /content/data/train/F0443/MID4/P04681_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID4/._P04681_face2.jpg
#   inflating: /content/data/train/F0443/MID3/P04680_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID3/._P04680_face5.jpg
#   inflating: /content/data/train/F0443/MID3/P04677_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID3/._P04677_face3.jpg
#   inflating: /content/data/train/F0443/MID3/P04681_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID3/._P04681_face3.jpg
#   inflating: /content/data/train/F0443/MID3/P04676_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID3/._P04676_face4.jpg
#   inflating: /content/data/train/F0443/MID3/P04678_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0443/MID3/._P04678_face2.jpg
#   inflating: /content/data/train/F0027/MID1/P00276_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00276_face1.jpg
#   inflating: /content/data/train/F0027/MID1/P00277_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00277_face1.jpg
#   inflating: /content/data/train/F0027/MID1/P00274_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00274_face1.jpg
#   inflating: /content/data/train/F0027/MID1/P00279_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00279_face1.jpg
#   inflating: /content/data/train/F0027/MID1/P00272_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00272_face2.jpg
#   inflating: /content/data/train/F0027/MID1/P00278_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00278_face3.jpg
#   inflating: /content/data/train/F0027/MID1/P00275_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID1/._P00275_face2.jpg
#   inflating: /content/data/train/F0027/MID2/P00270_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID2/._P00270_face1.jpg
#   inflating: /content/data/train/F0027/MID2/P00271_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID2/._P00271_face1.jpg
#   inflating: /content/data/train/F0027/MID4/P00276_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID4/._P00276_face2.jpg
#   inflating: /content/data/train/F0027/MID4/P00277_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID4/._P00277_face2.jpg
#   inflating: /content/data/train/F0027/MID4/P00279_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID4/._P00279_face2.jpg
#   inflating: /content/data/train/F0027/MID3/P00270_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID3/._P00270_face2.jpg
#   inflating: /content/data/train/F0027/MID3/P00271_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID3/._P00271_face2.jpg
#   inflating: /content/data/train/F0027/MID3/P00272_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID3/._P00272_face1.jpg
#   inflating: /content/data/train/F0027/MID3/P00275_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0027/MID3/._P00275_face1.jpg
#   inflating: /content/data/train/F0215/MID6/P11507_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID6/._P11507_face1.jpg
#   inflating: /content/data/train/F0215/MID6/P11506_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID6/._P11506_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P02282_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P02282_face2.jpg
#   inflating: /content/data/train/F0215/MID1/P11497_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11497_face5.jpg
#   inflating: /content/data/train/F0215/MID1/P11501_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11501_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11496_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11496_face3.jpg
#   inflating: /content/data/train/F0215/MID1/P11514_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11514_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P02279_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P02279_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11505_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11505_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11517_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11517_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11503_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11503_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11495_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11495_face3.jpg
#   inflating: /content/data/train/F0215/MID1/P02286_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P02286_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P02281_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P02281_face2.jpg
#   inflating: /content/data/train/F0215/MID1/P11499_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11499_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P02287_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P02287_face2.jpg
#   inflating: /content/data/train/F0215/MID1/P11494_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11494_face1.jpg
#   inflating: /content/data/train/F0215/MID1/P11504_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID1/._P11504_face4.jpg
#   inflating: /content/data/train/F0215/MID8/P11494_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID8/._P11494_face2.jpg
#   inflating: /content/data/train/F0215/MID8/P11499_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID8/._P11499_face2.jpg
#   inflating: /content/data/train/F0215/MID9/P11495_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID9/._P11495_face1.jpg
#   inflating: /content/data/train/F0215/MID9/P11504_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID9/._P11504_face1.jpg
#   inflating: /content/data/train/F0215/MID9/P11494_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID9/._P11494_face5.jpg
#   inflating: /content/data/train/F0215/MID2/P02279_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P02279_face2.jpg
#   inflating: /content/data/train/F0215/MID2/P11500_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11500_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P11495_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11495_face4.jpg
#   inflating: /content/data/train/F0215/MID2/P02280_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P02280_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P11494_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11494_face4.jpg
#   inflating: /content/data/train/F0215/MID2/P11510_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11510_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P02281_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P02281_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P11516_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11516_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P02287_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P02287_face1.jpg
#   inflating: /content/data/train/F0215/MID2/P11504_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID2/._P11504_face5.jpg
#   inflating: /content/data/train/F0215/MID5/P11513_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID5/._P11513_face1.jpg
#   inflating: /content/data/train/F0215/MID5/P11515_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID5/._P11515_face1.jpg
#   inflating: /content/data/train/F0215/MID5/P11514_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID5/._P11514_face2.jpg
#   inflating: /content/data/train/F0215/MID5/P02286_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID5/._P02286_face2.jpg
#   inflating: /content/data/train/F0215/MID5/P11517_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID5/._P11517_face2.jpg
#   inflating: /content/data/train/F0215/MID3/P02282_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P02282_face1.jpg
#   inflating: /content/data/train/F0215/MID3/P11512_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11512_face1.jpg
#   inflating: /content/data/train/F0215/MID3/P11496_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11496_face2.jpg
#   inflating: /content/data/train/F0215/MID3/P11511_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11511_face1.jpg
#   inflating: /content/data/train/F0215/MID3/P11495_face5.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11495_face5.jpg
#   inflating: /content/data/train/F0215/MID3/P11508_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11508_face1.jpg
#   inflating: /content/data/train/F0215/MID3/P11504_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11504_face3.jpg
#   inflating: /content/data/train/F0215/MID3/P11509_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0215/MID3/._P11509_face1.jpg
#   inflating: /content/data/train/F0215/MID3/P11494_face3.jpg
# ...
#   inflating: /content/__MACOSX/data/train/F0278/MID4/._P02966_face2.jpg
#   inflating: /content/data/train/F0278/MID4/P02960_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID4/._P02960_face2.jpg
#   inflating: /content/data/train/F0278/MID4/P02958_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID4/._P02958_face1.jpg
#   inflating: /content/data/train/F0278/MID4/P02959_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID4/._P02959_face1.jpg
#   inflating: /content/data/train/F0278/MID4/P02961_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID4/._P02961_face1.jpg
#   inflating: /content/data/train/F0278/MID3/P02964_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02964_face2.jpg
#   inflating: /content/data/train/F0278/MID3/P02957_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02957_face3.jpg
#   inflating: /content/data/train/F0278/MID3/P02965_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02965_face2.jpg
#   inflating: /content/data/train/F0278/MID3/P02966_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02966_face1.jpg
#   inflating: /content/data/train/F0278/MID3/P02960_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02960_face1.jpg
#   inflating: /content/data/train/F0278/MID3/P02958_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02958_face2.jpg
#   inflating: /content/data/train/F0278/MID3/P02961_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02961_face2.jpg
#   inflating: /content/data/train/F0278/MID3/P02959_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0278/MID3/._P02959_face2.jpg
#   inflating: /content/data/train/F0081/MID6/P00838_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID6/._P00838_face1.jpg
#   inflating: /content/data/train/F0081/MID6/P00837_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID6/._P00837_face3.jpg
#   inflating: /content/data/train/F0081/MID6/P00836_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID6/._P00836_face3.jpg
#   inflating: /content/data/train/F0081/MID1/P00833_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00833_face1.jpg
#   inflating: /content/data/train/F0081/MID1/P00835_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00835_face2.jpg
#   inflating: /content/data/train/F0081/MID1/P00832_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00832_face1.jpg
#   inflating: /content/data/train/F0081/MID1/P00834_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00834_face2.jpg
#   inflating: /content/data/train/F0081/MID1/P00839_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00839_face1.jpg
#   inflating: /content/data/train/F0081/MID1/P00836_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID1/._P00836_face1.jpg
#   inflating: /content/data/train/F0081/MID8/P00838_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID8/._P00838_face3.jpg
#   inflating: /content/data/train/F0081/MID7/P00836_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID7/._P00836_face4.jpg
#   inflating: /content/data/train/F0081/MID2/P00833_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00833_face2.jpg
#   inflating: /content/data/train/F0081/MID2/P00838_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00838_face2.jpg
#   inflating: /content/data/train/F0081/MID2/P00832_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00832_face2.jpg
#   inflating: /content/data/train/F0081/MID2/P00834_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00834_face1.jpg
#   inflating: /content/data/train/F0081/MID2/P00839_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00839_face2.jpg
#   inflating: /content/data/train/F0081/MID2/P00837_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00837_face1.jpg
#   inflating: /content/data/train/F0081/MID2/P00836_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0081/MID2/._P00836_face2.jpg
#   inflating: /content/data/train/F0247/MID1/P02612_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02612_face1.jpg
#   inflating: /content/data/train/F0247/MID1/P02614_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02614_face1.jpg
#   inflating: /content/data/train/F0247/MID1/P02613_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02613_face1.jpg
#   inflating: /content/data/train/F0247/MID1/P02609_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02609_face1.jpg
#   inflating: /content/data/train/F0247/MID1/P02608_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02608_face1.jpg
#   inflating: /content/data/train/F0247/MID1/P02617_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID1/._P02617_face1.jpg
#   inflating: /content/data/train/F0247/MID2/P02612_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02612_face2.jpg
#   inflating: /content/data/train/F0247/MID2/P02614_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02614_face2.jpg
#   inflating: /content/data/train/F0247/MID2/P02613_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02613_face2.jpg
#   inflating: /content/data/train/F0247/MID2/P02609_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02609_face2.jpg
#   inflating: /content/data/train/F0247/MID2/P02608_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02608_face2.jpg
#   inflating: /content/data/train/F0247/MID2/P02617_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID2/._P02617_face2.jpg
#   inflating: /content/data/train/F0247/MID3/P02609_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID3/._P02609_face3.jpg
#   inflating: /content/data/train/F0247/MID3/P02608_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID3/._P02608_face3.jpg
#   inflating: /content/data/train/F0247/MID3/P02617_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0247/MID3/._P02617_face3.jpg
#   inflating: /content/data/train/F0849/MID1/P08977_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08977_face2.jpg
#   inflating: /content/data/train/F0849/MID1/P08976_face4.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08976_face4.jpg
#   inflating: /content/data/train/F0849/MID1/P08970_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08970_face2.jpg
#   inflating: /content/data/train/F0849/MID1/P08978_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08978_face2.jpg
#   inflating: /content/data/train/F0849/MID1/P08975_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08975_face3.jpg
#   inflating: /content/data/train/F0849/MID1/P08973_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08973_face2.jpg
#   inflating: /content/data/train/F0849/MID1/P08974_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08974_face1.jpg
#   inflating: /content/data/train/F0849/MID1/P08979_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08979_face1.jpg
#   inflating: /content/data/train/F0849/MID1/P08972_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID1/._P08972_face1.jpg
#   inflating: /content/data/train/F0849/MID2/P08971_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08971_face1.jpg
#   inflating: /content/data/train/F0849/MID2/P08976_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08976_face2.jpg
#   inflating: /content/data/train/F0849/MID2/P08970_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08970_face1.jpg
#   inflating: /content/data/train/F0849/MID2/P08975_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08975_face1.jpg
#   inflating: /content/data/train/F0849/MID2/P08978_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08978_face1.jpg
#   inflating: /content/data/train/F0849/MID2/P08979_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08979_face3.jpg
#   inflating: /content/data/train/F0849/MID2/P08974_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0849/MID2/._P08974_face2.jpg
#   inflating: /content/data/train/F0075/MID1/P00764_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00764_face2.jpg
#   inflating: /content/data/train/F0075/MID1/P00769_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00769_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00770_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00770_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00762_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00762_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00771_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00771_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00765_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00765_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00768_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00768_face2.jpg
#   inflating: /content/data/train/F0075/MID1/P00763_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00763_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00766_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00766_face1.jpg
#   inflating: /content/data/train/F0075/MID1/P00772_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID1/._P00772_face1.jpg
#   inflating: /content/data/train/F0075/MID2/P00764_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID2/._P00764_face1.jpg
#   inflating: /content/data/train/F0075/MID2/P00769_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID2/._P00769_face3.jpg
#   inflating: /content/data/train/F0075/MID2/P00762_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID2/._P00762_face2.jpg
#   inflating: /content/data/train/F0075/MID2/P00768_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID2/._P00768_face1.jpg
#   inflating: /content/data/train/F0075/MID3/P00770_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00770_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00769_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00769_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00771_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00771_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00765_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00765_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00763_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00763_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00766_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00766_face2.jpg
#   inflating: /content/data/train/F0075/MID3/P00772_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0075/MID3/._P00772_face2.jpg
#   inflating: /content/data/train/F0411/MID1/P04326_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID1/._P04326_face2.jpg
#   inflating: /content/data/train/F0411/MID1/P04330_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID1/._P04330_face2.jpg
#   inflating: /content/data/train/F0411/MID2/P04327_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04327_face1.jpg
#   inflating: /content/data/train/F0411/MID2/P04326_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04326_face1.jpg
#   inflating: /content/data/train/F0411/MID2/P04325_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04325_face1.jpg
#   inflating: /content/data/train/F0411/MID2/P04328_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04328_face1.jpg
#   inflating: /content/data/train/F0411/MID2/P04330_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04330_face1.jpg
#   inflating: /content/data/train/F0411/MID2/P04329_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID2/._P04329_face1.jpg
#   inflating: /content/data/train/F0411/MID3/P04327_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID3/._P04327_face2.jpg
#   inflating: /content/data/train/F0411/MID3/P04328_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID3/._P04328_face2.jpg
#   inflating: /content/data/train/F0411/MID3/P04325_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID3/._P04325_face2.jpg
#   inflating: /content/data/train/F0411/MID3/P04329_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0411/MID3/._P04329_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06554_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06554_face1.jpg
#   inflating: /content/data/train/F0623/MID1/P06552_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06552_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06546_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06546_face1.jpg
#   inflating: /content/data/train/F0623/MID1/P06547_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06547_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06553_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06553_face1.jpg
#   inflating: /content/data/train/F0623/MID1/P06550_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06550_face1.jpg
#   inflating: /content/data/train/F0623/MID1/P06549_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06549_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06544_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06544_face1.jpg
#   inflating: /content/data/train/F0623/MID1/P06551_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06551_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06548_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06548_face2.jpg
#   inflating: /content/data/train/F0623/MID1/P06545_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID1/._P06545_face1.jpg
#   inflating: /content/data/train/F0623/MID2/P06554_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06554_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06552_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06552_face3.jpg
#   inflating: /content/data/train/F0623/MID2/P06546_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06546_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06547_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06547_face3.jpg
#   inflating: /content/data/train/F0623/MID2/P06553_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06553_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06550_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06550_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06549_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06549_face1.jpg
#   inflating: /content/data/train/F0623/MID2/P06544_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06544_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06545_face2.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06545_face2.jpg
#   inflating: /content/data/train/F0623/MID2/P06551_face1.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06551_face1.jpg
#   inflating: /content/data/train/F0623/MID2/P06548_face3.jpg
#   inflating: /content/__MACOSX/data/train/F0623/MID2/._P06548_face3.jpg

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from glob import glob
from collections import defaultdict
import torchvision
from random import choice
from torch.utils.data import Dataset
from PIL import Image
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.optim.lr_scheduler import ReduceLROnPlateau
# from torch.nn import Parameter
# from facenet_pytorch import InceptionResnetV1

# %% [markdown]
# ### Config

# %%
class Config:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    train_file_path = "./data/train-relationships/train_relationships.csv"
    train_folders_path = "/content/data/train/"
    val_famillies = "F09"
    test_relationship_file = "/content/data/submissions/sample_submission.csv"
    batch_size = 64
    number_of_epochs = 100

    learning_rate = 0.0005

    MIN_NUM_PATCHES = 16
    pretrained_vits = '/content/drive/MyDrive/face_transformer/Backbone_VITs_Epoch_2_Batch_12000_Time_2021-03-17-04-05_checkpoint.pth'
    pretrained_vit = '/content/drive/MyDrive/face_transformer/Backbone_VIT_Epoch_2_Batch_20000_Time_2021-01-12-16-48_checkpoint.pth'

# %% [markdown]
# ### Dataset

# %%
class KinDataset(Dataset):
    def __init__(self, relations, person_to_images_map, transform=None):
        self.relations = relations
        self.transform = transform
        self.person_to_images_map = person_to_images_map
        self.ppl = list(person_to_images_map.keys())

    def __len__(self):
        return len(self.relations)*2

    def __getitem__(self, idx):

        if idx%2==0: #Positive samples
            p1, p2 = self.relations[idx//2]
            label = 1
        else:          #TODO: better way to sample Negative samples
            while True:
                p1 = choice(self.ppl)
                p2 = choice(self.ppl)
                if p1 != p2 and (p1, p2) not in self.relations and (p2, p1) not in self.relations:
                    break
            label = 0

        path1, path2 = choice(self.person_to_images_map[p1]), choice(self.person_to_images_map[p2])
        img1, img2 = Image.open(path1), Image.open(path2)

        if self.transform:
            img1, img2 = self.transform(img1), self.transform(img2)

        return img1, img2, label

# %%
print("Prepare data...")
all_images = glob(Config.train_folders_path + "*/*/*.jpg")

train_images = [x for x in all_images if Config.val_famillies not in x]
val_images = [x for x in all_images if Config.val_famillies in x]

train_person_to_images_map = defaultdict(list)

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

relationships = pd.read_csv(Config.train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

train_relations = [x for x in relationships if Config.val_famillies not in x[0]]
val_relations  = [x for x in relationships if Config.val_famillies in x[0]]

train_transform = transforms.Compose([
    transforms.Resize(130),
    transforms.CenterCrop(112),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    transforms.RandomRotation(degrees=10),
    transforms.ToTensor(),
    transforms.Normalize([0., 0., 0.], [1/255., 1/255., 1/255.]),
])
val_transform = transforms.Compose([
    transforms.Resize(130),
    transforms.CenterCrop(112),
    transforms.ToTensor(),
    transforms.Normalize([0., 0., 0.], [1/255., 1/255., 1/255.]),
])

trainset = KinDataset(train_relations, train_person_to_images_map, train_transform)
valset = KinDataset(val_relations, val_person_to_images_map, val_transform)

trainloader = DataLoader(trainset, batch_size=Config.batch_size, shuffle=True)
valloader = DataLoader(valset, batch_size=Config.batch_size, shuffle=False)
# Out:
# Prepare data...

# %% [markdown]
# ### Model

# %%
class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(x, **kwargs) + x

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        inner_dim = dim_head *  heads
        self.heads = heads
        self.scale = dim ** -0.5

        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)
        self.linear_proj = nn.Linear(dim, inner_dim)
        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        )

    def forward(self, x, x2=None, alpha=0.8, mask=None):
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = h), qkv)
        qx2 = self.linear_proj(x2)
        qx2 = rearrange(qx2, 'b n (h d) -> b h n d', h = h)
        q = q * alpha + qx2 * (1-alpha)
        dots = torch.einsum('bhid,bhjd->bhij', q, k) * self.scale
        mask_value = -torch.finfo(dots.dtype).max
        #embed()
        if mask is not None:
            mask = F.pad(mask.flatten(1), (1, 0), value = True)
            assert mask.shape[-1] == dots.shape[-1], 'mask has incorrect dimensions'
            mask = mask[:, None, :] * mask[:, :, None]
            dots.masked_fill_(~mask, mask_value)
            del mask

        attn = dots.softmax(dim=-1)

        out = torch.einsum('bhij,bhjd->bhid', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        out =  self.to_out(out)

        return out

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout):
        super().__init__()
        self.layers = nn.ModuleList([])

        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                Residual(PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout))),
                Residual(PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout)))
            ]))
    def forward(self, x, x2, mask = None):
        for attn, ff in self.layers:
            x = attn(x, x2=x2)
            x = ff(x)
        return x

class ViTs_face(nn.Module):
    def __init__(self, *, loss_type, GPU_ID, num_class, image_size, patch_size, ac_patch_size,
                         pad, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        assert image_size % patch_size == 0, 'Image dimensions must be divisible by the patch size.'
        num_patches = (image_size // patch_size) ** 2
        patch_dim = channels * ac_patch_size ** 2
        assert num_patches > Config.MIN_NUM_PATCHES, f'your number of patches ({num_patches}) is way too small for attention to be effective (at least 16). Try decreasing your patch size'
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        self.patch_size = patch_size
        self.soft_split = nn.Unfold(kernel_size=(ac_patch_size, ac_patch_size), stride=(self.patch_size, self.patch_size), padding=(pad, pad))


        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.patch_to_embedding = nn.Linear(patch_dim, dim)
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.dropout = nn.Dropout(emb_dropout)

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
        )
        self.loss_type = loss_type
        self.GPU_ID = GPU_ID
        if self.loss_type == 'None':
            print("no loss for vit_face")

    def preprocess(self, img):
        x = self.soft_split(img).transpose(1, 2)
        x = self.patch_to_embedding(x)
        b, n, _ = x.shape

        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)
        return x

    def forward(self, img, label=None , mask=None, return_lhs=False):
        x = self.preprocess(img)
        x = self.transformer(x, mask)

        last_hidden_state = x.detach()
        # print('transformer_out', x.shape)

        x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]

        x = self.to_latent(x)
        emb = self.mlp_head(x)
        if label is not None:
            x = self.loss(emb, label)
            return x, emb
        elif return_lhs:
            return emb, last_hidden_state
        else:
            return emb

# %%
class SiameseNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder1 = self.build_encoder()
        self.encoder2 = self.build_encoder()
        self.sigmoid = nn.Sigmoid()
        self.embed_size = 512
        self.fc = nn.Sequential(
            nn.Linear(self.embed_size*3, self.embed_size*4),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(self.embed_size*4, self.embed_size*1),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(self.embed_size*1, self.embed_size//4),
            nn.ReLU(),
        )
        self.last = nn.Sequential(
            nn.Linear(self.embed_size//4+1,self.embed_size//16),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(self.embed_size//16, 1),
        )

    def build_encoder(self):
        model = ViTs_face(
            loss_type=None,
            GPU_ID=Config.device,
            num_class=93431,
            image_size=112,
            patch_size=8,
            ac_patch_size=12,
            pad=4,
            dim=512,
            depth=20,
            heads=8,
            mlp_dim=2048,
            dropout=0.1,
            emb_dropout=0.1
        )
        model.load_state_dict(torch.load(Config.pretrained_vits, map_location=Config.device), strict=False)
        for name, layer in model.named_parameters():
            if 'linear_proj' in name or '19' in name:
                # print(name)
                layer.requires_grad_(True)
            else:
                layer.requires_grad_(False)
        return model

    def forward(self, img1, img2, mask=None):
        x1 = self.encoder1.preprocess(img1)
        x2 = self.encoder2.preprocess(img2)

        for layer1, layer2 in zip(self.encoder1.transformer.layers, self.encoder2.transformer.layers):
            x1_new = layer1[0](x1, x2=x2, mask=mask)
            x1_new = layer1[1](x1_new)
            x2_new = layer2[0](x2, x2=x1, mask=mask)
            x2_new = layer2[1](x2_new)

        x1_new = x1_new.mean(dim = 1) if self.encoder1.pool == 'mean' else x1_new[:, 0]
        x2_new = x2_new.mean(dim = 1) if self.encoder2.pool == 'mean' else x2_new[:, 0]

        x1_new = self.encoder1.to_latent(x1_new)
        x2_new = self.encoder2.to_latent(x2_new)
        x1 = self.encoder1.mlp_head(x1_new)
        x2 = self.encoder2.mlp_head(x2_new)

        x3 = x1-x2
        x5 = torch.pow(x1,2)
        x6 = torch.pow(x2,2)
        x = torch.cat([x3,x5+x6,x1*x2],dim=-1)
        x = self.fc(x)
        cos_dis=1-F.cosine_similarity(x1,x2,dim=-1)
        x = torch.cat([x,cos_dis.unsqueeze(1)],dim=-1)
        result = self.last(x)
        result=torch.sigmoid(result)
        return result

# %% [markdown]
# ### Train

# %%
def train(net, criterion, optimizer):
    net.train()
    train_loss = 0.0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(trainloader):
        optimizer.zero_grad()

        img1, img2, label = batch
        img1, img2, label = img1.to(Config.device), img2.to(Config.device), label.float().view(-1,1).to(Config.device)
        output = net(img1, img2)
        preds = output>0.5

        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        running_loss += loss.item()
        running_corrects += torch.sum(preds == (label>0.5))

        step = 100
        if i % step == step-1:
            print(' [{} - {:.2f}%],\ttrain loss: {:.5}'.format(epoch+1, 100*(i+1)/len(trainloader), running_loss/step/200))
            running_loss = 0

    train_loss /= len(trainset)
    running_corrects = running_corrects.item()/len(trainset)
    print('[{}], \ttrain loss: {:.5}\tacc: {:.5}'.format(epoch+1, train_loss, running_corrects))
    return train_loss, running_corrects

# %%
def validate(net, criterion, optimizer):
    net.eval()
    val_loss = 0.0
    running_corrects = 0

    for batch in valloader:
        img1, img2, label = batch
        img1, img2, label = img1.to(Config.device), img2.to(Config.device), label.float().view(-1,1).to(Config.device)
        with torch.no_grad():
            output = net(img1, img2)
            preds = output>0.5
            loss = criterion(output, label)

        val_loss += loss.item()
        running_corrects += torch.sum(preds == (label>0.5))

    val_loss /= len(valset)
    running_corrects = running_corrects.item()/len(valset)
    print('[{}], \tval loss: {:.5}\tacc: {:.5}'.format(epoch+1, val_loss, running_corrects))

    return val_loss, running_corrects

# %%
print("Initialize network...")
net = SiameseNet().to(Config.device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(net.parameters(), lr=Config.learning_rate)
scheduler = ReduceLROnPlateau(optimizer, patience=10)

# %%
print("Start training...")

best_val_loss = 1000
best_val_acc = 0.0
best_epoch = 0

history = []
accuracy = []
for epoch in range(Config.number_of_epochs):
    train_loss, train_acc = train(net, criterion, optimizer)
    val_loss, val_acc = validate(net, criterion, optimizer)
    history.append((train_loss, val_loss))
    accuracy.append((train_acc,val_acc))
    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(net.state_dict(), './checkpoints/best_loss_inno2.pth')
        print('saving...')
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(net.state_dict(), './checkpoints/best_acc_inno2.pth')
        print('saving...')
# Out:
# Start training...
# [1], 	train loss: 0.010911	acc: 0.49608
# [1], 	val loss: 0.011739	acc: 0.5
# saving...
# saving...
# [2], 	train loss: 0.01088	acc: 0.50766
# [2], 	val loss: 0.011712	acc: 0.5
# saving...
# [3], 	train loss: 0.010882	acc: 0.50341
# [3], 	val loss: 0.011723	acc: 0.5
# [4], 	train loss: 0.010875	acc: 0.5046
# [4], 	val loss: 0.011703	acc: 0.5
# saving...
# [5], 	train loss: 0.010869	acc: 0.50426
# [5], 	val loss: 0.011718	acc: 0.5
# [6], 	train loss: 0.010867	acc: 0.50221
# [6], 	val loss: 0.01165	acc: 0.51689
# saving...
# saving...
# [7], 	train loss: 0.01085	acc: 0.51822
# [7], 	val loss: 0.01165	acc: 0.52872
# saving...
# [8], 	train loss: 0.010831	acc: 0.51907
# [8], 	val loss: 0.011259	acc: 0.53547
# saving...
# saving...
# [9], 	train loss: 0.010841	acc: 0.51141
# [9], 	val loss: 0.011707	acc: 0.5
# [10], 	train loss: 0.010853	acc: 0.50715
# [10], 	val loss: 0.011446	acc: 0.54054
# saving...
# [11], 	train loss: 0.010854	acc: 0.50596
# [11], 	val loss: 0.011701	acc: 0.49831
# [12], 	train loss: 0.010858	acc: 0.50647
# [12], 	val loss: 0.011636	acc: 0.5152
# [13], 	train loss: 0.010833	acc: 0.52095
# [13], 	val loss: 0.011573	acc: 0.51689
# [14], 	train loss: 0.010663	acc: 0.52963
# [14], 	val loss: 0.011478	acc: 0.52027
# [15], 	train loss: 0.010489	acc: 0.5608
# [15], 	val loss: 0.010694	acc: 0.60642
# saving...
# saving...
# [16], 	train loss: 0.010513	acc: 0.55313
# [16], 	val loss: 0.011124	acc: 0.5777
# [17], 	train loss: 0.010608	acc: 0.54326
# [17], 	val loss: 0.01108	acc: 0.55743
# [18], 	train loss: 0.010448	acc: 0.57204
# [18], 	val loss: 0.0106	acc: 0.60304
# saving...
# [19], 	train loss: 0.010449	acc: 0.56454
# [19], 	val loss: 0.011145	acc: 0.56757
# [20], 	train loss: 0.010434	acc: 0.55109
# [20], 	val loss: 0.010516	acc: 0.55743
# saving...
# [21], 	train loss: 0.01048	acc: 0.54837
# [21], 	val loss: 0.011075	acc: 0.57264
# [22], 	train loss: 0.010343	acc: 0.57084
# [22], 	val loss: 0.01085	acc: 0.57432
# [23], 	train loss: 0.010472	acc: 0.55211
# [23], 	val loss: 0.01085	acc: 0.54561
# [24], 	train loss: 0.010419	acc: 0.5499
# [24], 	val loss: 0.010833	acc: 0.54899
# [25], 	train loss: 0.010399	acc: 0.56165
# [25], 	val loss: 0.010928	acc: 0.59122
# [26], 	train loss: 0.010375	acc: 0.56352
# [26], 	val loss: 0.011183	acc: 0.59291
# [27], 	train loss: 0.010277	acc: 0.56829
# [27], 	val loss: 0.011032	acc: 0.56757
# [28], 	train loss: 0.010323	acc: 0.5608
# [28], 	val loss: 0.010859	acc: 0.58108
# [29], 	train loss: 0.010321	acc: 0.57374
# [29], 	val loss: 0.010676	acc: 0.60473
# [30], 	train loss: 0.010334	acc: 0.56574
# [30], 	val loss: 0.010506	acc: 0.59291
# saving...
# [31], 	train loss: 0.010367	acc: 0.56574
# [31], 	val loss: 0.011281	acc: 0.57095
# [32], 	train loss: 0.010437	acc: 0.55433
# [32], 	val loss: 0.010655	acc: 0.59628
# [33], 	train loss: 0.010363	acc: 0.56199
# [33], 	val loss: 0.010915	acc: 0.59797
# [34], 	train loss: 0.010404	acc: 0.56676
# [34], 	val loss: 0.010934	acc: 0.58446
# [35], 	train loss: 0.010427	acc: 0.56812
# [35], 	val loss: 0.010834	acc: 0.58953
# [36], 	train loss: 0.010438	acc: 0.56778
# [36], 	val loss: 0.010822	acc: 0.59122
# [37], 	train loss: 0.01044	acc: 0.56557
# [37], 	val loss: 0.010848	acc: 0.58108
# [38], 	train loss: 0.010391	acc: 0.56948
# [38], 	val loss: 0.010881	acc: 0.56757
# [39], 	train loss: 0.010395	acc: 0.56063
# [39], 	val loss: 0.010768	acc: 0.59628
# [40], 	train loss: 0.010447	acc: 0.56659
# [40], 	val loss: 0.010983	acc: 0.55068
# [41], 	train loss: 0.010356	acc: 0.56471
# [41], 	val loss: 0.010572	acc: 0.57432
# [42], 	train loss: 0.010399	acc: 0.56574
# [42], 	val loss: 0.010771	acc: 0.56926
# [43], 	train loss: 0.010342	acc: 0.56965
# [43], 	val loss: 0.010788	acc: 0.57264
# [44], 	train loss: 0.010326	acc: 0.57033
# [44], 	val loss: 0.010659	acc: 0.57432
# [45], 	train loss: 0.010289	acc: 0.56914
# [45], 	val loss: 0.010978	acc: 0.56757
# [46], 	train loss: 0.010308	acc: 0.56676
# [46], 	val loss: 0.011026	acc: 0.58277
# [47], 	train loss: 0.010324	acc: 0.57374
# [47], 	val loss: 0.010694	acc: 0.6098
# saving...
# [48], 	train loss: 0.010332	acc: 0.57561
# [48], 	val loss: 0.010953	acc: 0.57601
# [49], 	train loss: 0.01032	acc: 0.56352
# [49], 	val loss: 0.010551	acc: 0.6098
# [50], 	train loss: 0.010259	acc: 0.5814
# [50], 	val loss: 0.011246	acc: 0.55574
# [51], 	train loss: 0.01041	acc: 0.56574
# [51], 	val loss: 0.010609	acc: 0.58953

# %% [markdown]
# ### Submission

# %%
class FamilyTestDataset(Dataset):
    def __init__(self, relations, data_dir, transform):
        """
        Args:
            relations (string): Data frame with the image paths.
            data_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.relations = relations
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self) -> int:
        return len(self.relations)

    def __getpair__(self, idx):
        pair = (
            os.path.join(self.data_dir, self.relations.iloc[idx, 0].split("-")[0]),
            os.path.join(self.data_dir, self.relations.iloc[idx, 0].split("-")[1]),
        )
        return pair

    def __getlabel__(self, idx) -> int:
        return self.relations.iloc[idx, 1]

    def __getitem__(self, idx):
        pair = self.__getpair__(idx)

        im1 = Image.open(pair[0])
        im2 = Image.open(pair[1])

        img1 = self.transform(im1)
        img2 = self.transform(im2)

        return idx, img1, img2
def create_test_dataloader(test_image_dir: str, test_relationship_file: str):
    df = pd.read_csv(test_relationship_file)

    transform = transforms.Compose([
        transforms.Resize(112),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0., 0., 0.],
                             std=[1/255., 1/255., 1/255.])
    ])

    test_dataset = FamilyTestDataset(
        relations=df, data_dir=test_image_dir, transform=transform
    )

    test_loader = DataLoader(
        test_dataset,
        shuffle=True,
        batch_size=200,
    )

    return test_loader

# %%
def load_classifier(path_to_model_weights: str):
    model = SiameseNet()
    model.load_state_dict(torch.load(path_to_model_weights))
    return model

def create_submission(path_to_template: str, path_to_save: str, predictions):
    template = pd.read_csv(path_to_template)

    # Remember to save as floats as metric is AUC
    for row, pred in predictions.items():
        template.loc[row, "is_related"] = float(pred)

    template.to_csv(path_or_buf=path_to_save, index=False)
    return


def test_classifier(classifier, test_loader):
    predictions = {}

    classifier.to(Config.device)
    classifier.eval()
    for i, data in enumerate(test_loader):
        row, img1, img2 = data
        row, img1, img2 = row.to(Config.device), img1.to(Config.device), img2.to(Config.device)

        with torch.no_grad():
            output = classifier(img1, img2)

        for j in range(len(row)):
            predictions[row[j].item()] = output[j].item()

    return predictions


if __name__ == "__main__":
    path_to_model_weights = "./checkpoints/best_loss_inno.pth"
    path_to_template = "./data/submissions/sample_submission.csv"
    path_to_save = "./data/submissions/loss_inno.csv"

    classifier = load_classifier(path_to_model_weights)

    test_loader = create_test_dataloader(
        "/content/data/test",
        "/content/data/submissions/sample_submission.csv"
    )

    predictions = test_classifier(
        classifier=classifier, test_loader=test_loader
    )
    print(len(predictions))

    create_submission(
        path_to_template=path_to_template,
        path_to_save=path_to_save,
        predictions=predictions,
    )
# Out:
# 5310
